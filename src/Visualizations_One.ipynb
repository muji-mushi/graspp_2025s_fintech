# %% [markdown]
# # Visualizations of Data

# %%
#Necessary Importations
import pandas as pd
import requests
import io
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Necessary Lists

# %%
asean_list = ['VNM','LAO','THA','KHM','MYS','SGP','MMR','PHL','BRN','IDN']
south_asia_list = ['BGD','IND','PAK','NPL','LKA','BTN']
all_countries_list = ['VNM','LAO','THA','KHM','MYS','SGP','MMR','PHL','BRN','IDN','BGD','IND','PAK','NPL','LKA','BTN']

# %%
df_merged = pd.read_csv("..\data\processed\merged_data_2.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\user\AppData\Local\Temp\ipykernel_18980\115161635.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df_merged = pd.read_csv("..\data\processed\merged_data_2.csv")

# %%
df_merged.head()
# Out:
#   code  year  FarmCredit  ICTPolicy  ProductionValue  ProcessingValue  \
# 0  AFG  2011         NaN        NaN              NaN              NaN
# 1  AFG  2012         NaN        NaN              NaN              NaN
# 2  AFG  2013         NaN        NaN              NaN              NaN
# 3  AFG  2014         NaN        NaN              NaN              NaN
# 4  AFG  2015         NaN        NaN              NaN              NaN
#
#    Fertilizer  Rural Access to Electricity(Percent of Population)  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
#
#    Mobile Cellular Subscriptions (per 100 people)  \
# 0                                             NaN
# ...

# %%
df_merged = df_merged[df_merged['code'].isin(all_countries_list)]

# %%
df_merged.head()
# Out:
#    code  year   FarmCredit  ICTPolicy  ProductionValue  ProcessingValue  \
# 12  BGD  2011  3271.100803        NaN     1.649775e+06              NaN
# 13  BGD  2012  3213.392664        NaN     1.854820e+06    249808.744409
# 14  BGD  2012  3213.392664        NaN     1.854820e+06      3669.694917
# 15  BGD  2013  3296.803356        NaN     2.046421e+06              NaN
# 16  BGD  2014  3524.704970        NaN     2.304186e+06              NaN
#
#     Fertilizer  Rural Access to Electricity(Percent of Population)  \
# 12         NaN                                                NaN
# 13         NaN                                                NaN
# 14         NaN                                                NaN
# 15         NaN                                                NaN
# 16         NaN                                                NaN
#
#     Mobile Cellular Subscriptions (per 100 people)  \
# 12                                             NaN
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
df_merged['FarmCredit'].describe()
# Out:
# count      42.000000
# mean     2219.820062
# std      2005.520826
# min        13.788605
# 25%        80.813000
# 50%      1693.174178
# 75%      3853.768926
# max      6122.736320
# Name: FarmCredit, dtype: float64

# %% [markdown]
# # By Country

# %%
# Farm Credit
df_FarmCredit_Country = df_merged.groupby('code')['FarmCredit'].describe()
df_FarmCredit_Country.head()
# Out:
#       count         mean         std          min          25%          50%  \
# code
# BGD    16.0  4380.652326  936.422286  3213.392664  3467.729566  4542.845917
# BRN     0.0          NaN         NaN          NaN          NaN          NaN
# BTN    13.0    56.337145   24.944172    13.788605    36.919514    57.475975
# IDN     0.0          NaN         NaN          NaN          NaN          NaN
# IND     0.0          NaN         NaN          NaN          NaN          NaN
#
#               75%          max
# code
# BGD   4885.181503  6122.736320
# BRN           NaN          NaN
# BTN     79.122159    85.779739
# IDN           NaN          NaN
# IND           NaN          NaN

# %%
#Plotting Farm Credit
FarmCredit_Plot = df_FarmCredit_Country['mean'].sort_values()
FarmCredit_Plot.plot(kind='barh')
plt.title("Mean Farm Credit By Country Over Sample")
